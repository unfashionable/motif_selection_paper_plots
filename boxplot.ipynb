# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
enrichment = pd.read_csv("enrichment_MS_summary.csv",usecols = [0,1,2,3,4,5,6],header = None)
enrichment.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
greedy = pd.read_csv("greedy_result.csv",usecols = [0,1,2,3,4,5,6],header = None)
greedy.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
p_value = pd.read_csv("p_value_result.csv",usecols = [0,1,2,3,4,5,6],header = None)
p_value.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
RF_filtering = pd.read_csv("RF_filtering_result.csv",usecols = [0,1,2,3,4,5,6],header = None)
RF_filtering.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
RILP = pd.read_csv("RILP_result.csv",usecols = [0,1,2,3,4,5,6],header = None)
RILP.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
Tabu_PNPSC = pd.read_csv("Tabu_PNPSC_result.csv",usecols = [0,1,2,3,4,5,6],header = None)
Tabu_PNPSC.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
enrichment_new = pd.melt(enrichment, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
enrichment_new['method'] = "Enrichment"
greedy_new = pd.melt(greedy, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
greedy_new['method'] = "Greedy"
p_value_new = pd.melt(p_value, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
p_value_new['method'] = "Z-test"
RF_filtering_new = pd.melt(RF_filtering, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
RF_filtering_new['method'] = "Random_Forest"
RILP_new = pd.melt(RILP, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
RILP_new['method'] = "RILP"
Tabu_PNPSC_new = pd.melt(Tabu_PNPSC, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
Tabu_PNPSC_new['method'] = "Tabu_PNPSC"
frames = [enrichment_new, greedy_new, RF_filtering_new,RILP_new,Tabu_PNPSC_new,p_value_new]
result = pd.concat(frames)

# %%
result
# Out:
#       Groups     variable      value      method
# 0        E2F  Sensitivity   0.865200  Enrichment
# 1       HNF4  Sensitivity   0.766800  Enrichment
# 2        MYC  Sensitivity   0.793800  Enrichment
# 3       GATA  Sensitivity   0.642900  Enrichment
# 4      TFAP2  Sensitivity   0.838800  Enrichment
# 5        IRF  Sensitivity   0.824300  Enrichment
# 6        ETS  Sensitivity   0.899100  Enrichment
# 7      NR3C1  Sensitivity   0.747100  Enrichment
# 8       STAT  Sensitivity   0.786100  Enrichment
# 9       ATF3  Sensitivity   0.712309  Enrichment
# 10    POU2F2  Sensitivity   0.580600  Enrichment
# 11      RXRA  Sensitivity   0.594400  Enrichment
# 12      EGR1  Sensitivity   0.898400  Enrichment
# 13      MEF2  Sensitivity   0.502000  Enrichment
# 14       MAF  Sensitivity   0.599800  Enrichment
# 15     ESRRA  Sensitivity   0.666500  Enrichment
# 16      NFKB  Sensitivity   0.706000  Enrichment
# 17       AP1  Sensitivity   0.865100  Enrichment
# 18     CEBPB  Sensitivity   0.316800  Enrichment
# 19       SRF  Sensitivity   0.521400  Enrichment
# 20      RFX5  Sensitivity   0.423300  Enrichment
# 21       SP1  Sensitivity   0.630700  Enrichment
# 22      FOXA  Sensitivity   0.600800  Enrichment
# 23       YY1  Sensitivity   0.796300  Enrichment
# 24      SIX5  Sensitivity   0.547041  Enrichment
# 25    TCF7L2  Sensitivity   0.445000  Enrichment
# 26      TATA  Sensitivity   0.863800  Enrichment
# 27       NFY  Sensitivity   0.842700  Enrichment
# 28     SREBP  Sensitivity   0.264843  Enrichment
# 29      PAX5  Sensitivity   0.718100  Enrichment
# ..       ...          ...        ...         ...
# 294     SIX5   Num_motifs   3.000000      Z-test
# 295   TCF7L2   Num_motifs  10.000000      Z-test
# 296     TATA   Num_motifs   5.000000      Z-test
# 297      NFY   Num_motifs   2.000000      Z-test
# 298    SREBP   Num_motifs   4.000000      Z-test
# 299     PAX5   Num_motifs  20.000000      Z-test
# 300   POU5F1   Num_motifs   4.000000      Z-test
# 301     TAL1   Num_motifs   3.000000      Z-test
# 302      HSF   Num_motifs   3.000000      Z-test
# 303     REST   Num_motifs  10.000000      Z-test
# 304     SPI1   Num_motifs   5.000000      Z-test
# 305  BHLHE40   Num_motifs  10.000000      Z-test
# 306     EBF1   Num_motifs  10.000000      Z-test
# 307   ZBTB7A   Num_motifs   5.000000      Z-test
# 308     ELF1   Num_motifs   5.000000      Z-test
# 309     CTCF   Num_motifs   4.000000      Z-test
# 310     NFE2   Num_motifs   2.000000      Z-test
# 311   ZNF143   Num_motifs   4.000000      Z-test
# 312     NRF1   Num_motifs   4.000000      Z-test
# 313    PRDM1   Num_motifs   2.000000      Z-test
# 314    BRCA1   Num_motifs   5.000000      Z-test
# 315    EP300   Num_motifs  10.000000      Z-test
# 316    TCF12   Num_motifs  10.000000      Z-test
# 317    NANOG   Num_motifs   3.000000      Z-test
# 318   ZBTB33   Num_motifs  10.000000      Z-test
# 319     BATF   Num_motifs   5.000000      Z-test
# 320    NR2C2   Num_motifs  20.000000      Z-test
# 321     PBX3   Num_motifs  10.000000      Z-test
# 322     HEY1   Num_motifs   3.000000      Z-test
# 323     MXI1   Num_motifs  10.000000      Z-test
#
# [1950 rows x 4 columns]

# %%
f, ax = plt.subplots(figsize=(12, 16))
sns.set(style="ticks")

# Draw a nested boxplot to show bills by day and sex

sns.boxplot(x="value", y="variable", hue="method", data=result[result['variable']!="Num_motifs"],palette=sns.hls_palette(6,l=0.8))

sns.swarmplot(x="value", y="variable",hue="method", data=result[result['variable']!="Num_motifs"],split =True,palette=sns.hls_palette(6))
handles, labels = ax.get_legend_handles_labels()

# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = ax.legend(handles[6:], labels[6:], bbox_to_anchor=(0.09, 0.5), loc=2, borderaxespad=0.2,prop={'size': 20})
ax.tick_params(labelsize=20)
l.draw_frame(True)
ax.set_xlabel('')
ax.set_ylabel('')
# ax.set_xlim([0.2, 1])
# ax.set_title('Number of Motifs',fontsize=30)

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.set(style="ticks")

# Draw a nested boxplot to show bills by day and sex

sns.boxplot(x="value", y="variable", hue="method", data=result[result['variable']=="Num_motifs"],palette=sns.hls_palette(6,l=0.8))

sns.swarmplot(x="value", y="variable",hue="method", data=result[result['variable']=="Num_motifs"],split =True,palette=sns.hls_palette(6))
handles, labels = ax.get_legend_handles_labels()

# When creating the legend, only use the first two elements
# to effectively remove the last two.
# l = ax.legend(handles[6:], labels[6:], bbox_to_anchor=(0.09, 0.5), loc=2, borderaxespad=0.2,prop={'size': 20})
ax.tick_params(labelsize=20)
l.draw_frame(True)
ax.set_xlabel('')
ax.set_ylabel('')
ax.legend_.remove()
# ax.set_xlim([0.2, 1])
# ax.set_title('Number of Motifs',fontsize=30)

# %%
f, ax = plt.subplots(figsize=(12, 16))
sns.set(style="ticks")

# Draw a nested boxplot to show bills by day and sex

sns.boxplot(x="value", y="variable", hue="method", data=result,palette=sns.hls_palette(6,l=0.8))

sns.swarmplot(x="value", y="variable",hue="method", data=result,split =True,palette=sns.hls_palette(6))
handles, labels = ax.get_legend_handles_labels()

# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = ax.legend(handles[6:], labels[6:], bbox_to_anchor=(0.09, 0.5), loc=2, borderaxespad=0.2,prop={'size': 20})
ax.tick_params(labelsize=20)
l.draw_frame(True)
ax.set_xlabel('')
ax.set_ylabel('')
# ax.set_xlim([0.2, 1])
# ax.set_title('Number of Motifs',fontsize=30)

# %%
enrichment = pd.read_csv("enrichment_MS_summary.csv",usecols = [6],header = None)
enrichment.columns = ["Num_motifs"]
greedy = pd.read_csv("greedy_result.csv",usecols = [6],header = None)
greedy.columns = ["Num_motifs"]
p_value = pd.read_csv("p_value_result.csv",usecols = [6],header = None)
p_value.columns = ["Num_motifs"]
RF_filtering = pd.read_csv("RF_filtering_result.csv",usecols = [6],header = None)
RF_filtering.columns = ["Num_motifs"]
RILP = pd.read_csv("RILP_result.csv",usecols = [6],header = None)
RILP.columns = ["Num_motifs"]
Tabu_PNPSC = pd.read_csv("Tabu_PNPSC_result.csv",usecols = [6],header = None)
Tabu_PNPSC.columns = ["Num_motifs"]
enrichment_new = pd.melt(enrichment, value_vars=["Num_motifs"])
enrichment_new['method'] = "enrichment"
greedy_new = pd.melt(greedy, value_vars=["Num_motifs"])
greedy_new['method'] = "greedy"
p_value_new = pd.melt(p_value, value_vars=["Num_motifs"])
p_value_new['method'] = "p_value"
RF_filtering_new = pd.melt(RF_filtering, value_vars=["Num_motifs"])
RF_filtering_new['method'] = "RF_filtering"
RILP_new = pd.melt(RILP, value_vars=["Num_motifs"])
RILP_new['method'] = "RILP"
Tabu_PNPSC_new = pd.melt(Tabu_PNPSC, value_vars=["Num_motifs"])
Tabu_PNPSC_new['method'] = "Tabu_PNPSC"
frames = [enrichment_new, greedy_new, RF_filtering_new,RILP_new,Tabu_PNPSC_new,p_value_new]
result = pd.concat(frames)
f, ax = plt.subplots(figsize=(8, 6))
sns.set(style="ticks")

# Draw a nested boxplot to show bills by day and sex

sns.boxplot(x="value", y="method", data=result,palette=sns.hls_palette(6,l=0.8))

sns.swarmplot(x="value", y="method", data=result,split =True,palette=sns.hls_palette(6))
handles, labels = ax.get_legend_handles_labels()
ax.set_xlim([0, 10])
ax.tick_params(labelsize=20)
ax.set_xlabel('')
ax.set_ylabel('')
# When creating the legend, only use the first two elements
# to effectively remove the last two.
# l = plt.legend(handles[4:], labels[4:], bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.set(style="ticks")

# Draw a nested boxplot to show bills by day and sex

sns.boxplot(x="value", y="method", data=result,palette=sns.hls_palette(6,l=0.8))

sns.swarmplot(x="value", y="method", data=result,split =True,palette=sns.hls_palette(6))
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=20)
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_title('Number of Motifs',fontsize=30)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.set(style="ticks")

# Draw a nested boxplot to show bills by day and sex

sns.boxplot(x="value", y="method", data=result,palette=sns.hls_palette(4,l=0.8))

sns.swarmplot(x="value", y="method", data=result,split =True,palette=sns.hls_palette(4))
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=20)
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xlim([0, 12])
# ax.set_title('Number of Motifs',fontsize=30)
# Out:
# (0, 12)

# %%
result.method.unique()
# Out:
# array(['enrichment', 'greedy', 'p_value', 'RF_filtering'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
attend = sns.load_dataset("attention")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
enrichment = pd.read_csv("enrichment_MS_summary.csv",usecols = [0,1,2,3,4,5],header = None)
enrichment.columns = ["Groups","Sensitivity","Specificity","Accuracy","auROC","auPRC"]
greedy = pd.read_csv("greedy_result.csv",usecols = [0,1,2,3,4,5],header = None)
greedy.columns = ["Groups","Sensitivity","Specificity","Accuracy","auROC","auPRC"]
p_value = pd.read_csv("p_value_result.csv",usecols = [0,1,2,3,4,5],header = None)
p_value.columns = ["Groups","Sensitivity","Specificity","Accuracy","auROC","auPRC"]
RF_filtering = pd.read_csv("RF_filtering_result.csv",usecols = [0,1,2,3,4,5],header = None)
RF_filtering.columns = ["Groups","Sensitivity","Specificity","Accuracy","auROC","auPRC"]
RILP = pd.read_csv("RILP_result.csv",usecols = [0,1,2,3,4,5],header = None)
RILP.columns = ["Groups","Sensitivity","Specificity","Accuracy","auROC","auPRC"]
Tabu_PNPSC = pd.read_csv("Tabu_PNPSC_result.csv",usecols = [0,1,2,3,4,5],header = None)
Tabu_PNPSC.columns = ["Groups","Sensitivity","Specificity","Accuracy","auROC","auPRC"]
enrichment['FPR'] = 1-enrichment['Specificity']
greedy['FPR'] = 1-greedy['Specificity']
p_value['FPR'] = 1-p_value['Specificity']
RF_filtering['FPR'] = 1-RF_filtering['Specificity']
RILP['FPR'] = 1-RILP['Specificity']
Tabu_PNPSC['FPR'] = 1-Tabu_PNPSC['Specificity']
enrichment_new = pd.melt(enrichment, value_vars=["Sensitivity","Specificity","Accuracy","auROC","auPRC","FPR"])
enrichment_new['method'] = "enrichment"
greedy_new = pd.melt(greedy, value_vars=["Sensitivity","Specificity","Accuracy","auROC","auPRC","FPR"])
greedy_new['method'] = "greedy"
p_value_new = pd.melt(p_value, value_vars=["Sensitivity","Specificity","Accuracy","auROC","auPRC","FPR"])
p_value_new['method'] = "p_value"
RF_filtering_new = pd.melt(RF_filtering, value_vars=["Sensitivity","Specificity","Accuracy","auROC","auPRC","FPR"])
RF_filtering_new['method'] = "RF_filtering"
RILP_new = pd.melt(RILP, value_vars=["Sensitivity","Specificity","Accuracy","auROC","auPRC","FPR"])
RILP_new['method'] = "RILP"
Tabu_PNPSC_new = pd.melt(Tabu_PNPSC, value_vars=["Sensitivity","Specificity","Accuracy","auROC","auPRC","FPR"])
Tabu_PNPSC_new['method'] = "Tabu_PNPSC"
frames = [enrichment_new, greedy_new, RF_filtering_new,RILP_new,Tabu_PNPSC_new,p_value_new]
result = pd.concat(frames)

# %%
sns.pointplot(x="value", y="variable", hue="method",data=result)

# %%
test=pd.melt(enrichment, value_vars=["Sensitivity","Specificity","Accuracy","auROC","auPRC","FPR"],id_vars='Groups')

# %%
test
# Out:
#       Groups     variable     value
# 0        E2F  Sensitivity  0.841200
# 1       HNF4  Sensitivity  0.652400
# 2        MYC  Sensitivity  0.760300
# 3       GATA  Sensitivity  0.480000
# 4      TFAP2  Sensitivity  0.838800
# 5        IRF  Sensitivity  0.636400
# 6        ETS  Sensitivity  0.869100
# 7      NR3C1  Sensitivity  0.709000
# 8       STAT  Sensitivity  0.556200
# 9       ATF3  Sensitivity  0.712302
# 10    POU2F2  Sensitivity  0.580600
# 11      RXRA  Sensitivity  0.519400
# 12      EGR1  Sensitivity  0.841000
# 13      MEF2  Sensitivity  0.493800
# 14       MAF  Sensitivity  0.599800
# 15     ESRRA  Sensitivity  0.666500
# 16      NFKB  Sensitivity  0.706000
# 17       AP1  Sensitivity  0.660300
# 18     CEBPB  Sensitivity  0.282100
# 19       SRF  Sensitivity  0.521400
# 20      RFX5  Sensitivity  0.378200
# 21       SP1  Sensitivity  0.630700
# 22      FOXA  Sensitivity  0.481700
# 23       YY1  Sensitivity  0.783300
# 24      SIX5  Sensitivity  0.475135
# 25    TCF7L2  Sensitivity  0.445000
# 26      TATA  Sensitivity  0.731800
# 27       NFY  Sensitivity  0.842700
# 28     SREBP  Sensitivity  0.264938
# 29      PAX5  Sensitivity  0.646400
# ..       ...          ...       ...
# 300   TCF7L2          FPR  0.128000
# 301     TATA          FPR  0.123200
# 302      NFY          FPR  0.046400
# 303    SREBP          FPR  0.054774
# 304     PAX5          FPR  0.206300
# 305   POU5F1          FPR  0.121904
# 306     TAL1          FPR  0.138100
# 307      HSF          FPR  1.000000
# 308     ZEB1          FPR  0.094789
# 309     REST          FPR  0.162400
# 310     SPI1          FPR  0.197600
# 311  BHLHE40          FPR  0.122665
# 312     EBF1          FPR  0.153600
# 313   ZBTB7A          FPR  0.046154
# 314     ELF1          FPR  0.098900
# 315     CTCF          FPR  0.144300
# 316     NFE2          FPR  0.087242
# 317   ZNF143          FPR  0.125200
# 318     NRF1          FPR  0.059900
# 319    PRDM1          FPR  0.144968
# 320    BRCA1          FPR  0.003415
# 321    EP300          FPR  0.274800
# 322    TCF12          FPR  0.226100
# 323    NANOG          FPR  0.275700
# 324   ZBTB33          FPR  0.060107
# 325     BATF          FPR  0.132400
# 326    NR2C2          FPR  0.146054
# 327     PBX3          FPR  0.154335
# 328     HEY1          FPR  0.071500
# 329     MXI1          FPR  0.071198
#
# [330 rows x 3 columns]

# %%
sns.pointplot(x="Groups", y="value", hue="variable",data=test)
